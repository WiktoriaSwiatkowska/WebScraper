# %% [markdown]
# Packages Import

# %%
import os
import datetime
import uuid
import pandas as pd
from icalendar import Calendar, Event,vDatetime

# %% [markdown]
# Calendar export

# %%
group_name = input("Enter your group name:")

# %%
classes = pd.read_csv(f"schedules/{group_name}.csv", encoding= "UTF-8")

# %%
classes
# Out:
#      Unnamed: 0      Termin                                Przedmiot  \
# 0             1  2026-02-23                   Computer Programming 2
# 1             4  2026-02-24               Probability and Statistics
# 2             6  2026-02-24               Probability and Statistics
# 3             8  2026-02-24                     Discrete mathematics
# 4             9  2026-02-24                             Business Law
# ..          ...         ...                                      ...
# 118         304  2026-06-11                      Information Systems
# 119         305  2026-06-11  Operating Systems and Computer Networks
# 120         307  2026-06-17                     Discrete mathematics
# 121         308  2026-06-26  Operating Systems and Computer Networks
# 122         309  2026-09-03                     Discrete mathematics
#
#            Typ                        Nauczyciel                  Sala Day  \
# 0    ćwiczenia               dr Katarzyna Wójcik        Paw.A 013 lab.  Pn
# 1       wykład  prof. dr hab. Andrzej Sokołowski             Paw.F 008  Wt
# 2    ćwiczenia  prof. dr hab. Andrzej Sokołowski         Paw.A 07 lab.  Wt
# 3       wykład           dr Grzegorz Kosiorowski  Rakowicka 16 sala 11  Wt
# 4       wykład                  dr Jacek Lachner  Rakowicka 16 sala 11  Wt
# ..         ...                               ...                   ...  ..
# 118  ćwiczenia           mgr inż. Justyna Olczak        Paw.A 014 lab.  Cz
# 119  ćwiczenia  prof. UEK dr hab. Joanna Wyrobek         Paw.A 07 lab.  Cz
# 120    egzamin           dr Grzegorz Kosiorowski       Paw.C Nowa Aula  Śr
# 121    egzamin  prof. UEK dr hab. Joanna Wyrobek         Paw.A 07 lab.  Pt
# 122    egzamin           dr Grzegorz Kosiorowski             Paw.F 102  Cz
#
#     Start time End time  Duration
# 0        13:15    15:45         3
# 1        09:45    11:15         2
# 2        13:15    14:45         2
# 3        15:00    16:30         2
# 4        18:30    20:00         2
# ..         ...      ...       ...
# 118      16:45    17:30         1
# 119      18:30    20:00         2
# 120      10:30    13:00         3
# 121      10:30    12:15         2
# 122      10:30    13:00         3
#
# [123 rows x 10 columns]

# %%
if not os.path.exists("calendars"):
    os.mkdir("calendars")

# %%
calendar = Calendar()
calendar["dtstart"]= "20260223T0000"
calendar["dtend"]= "20260930T235999"
calendar["summary"]= f"Schedule of the {group_name} group."
calendar["version"]= "2.0"
calendar["PERIOD"]= f"-//Apollo schedule export//{group_name}"
calendar["tzname"]="CEST"

# %%
for index, row in classes.iterrows():
    event= Event()
    event["dtstart"] =row["Termin"].replace("-","")+"T"+row["Start time"].replace(":","")+"00"
    event["dtend"]=row["Termin"].replace("-","")+"T"+row["End time"].replace(":","")+"00"
    event["location"]= row["Sala"]
    event["summary"]= row["Przedmiot"]
    event["descrition"]= row["Nauczyciel"]
    event["UID"]= uuid.uuid4()
    event["DTSTAMP"]= vDatetime(datetime.datetime.now())
    calendar.add_component(event)

# %%
print(calendar.to_ical())
# Out:
# b'BEGIN:VCALENDAR\r\nVERSION:2.0\r\nDTEND:20260930T235999\r\nDTSTART:20260223T0000\r\nPERIOD:-//Apollo schedule export//ZICSS1-1211\r\nSUMMARY:Schedule of the ZICSS1-1211 group.\r\nTZNAME:CEST\r\nBEGIN:VEVENT\r\nSUMMARY:Computer Programming 2\r\nDTSTART:20260223T131500\r\nDTEND:20260223T154500\r\nDTSTAMP:20260525T151451\r\nUID:05f9caf7-51d7-4970-ad66-b6f4d15db4e3\r\nDESCRITION:dr Katarzyna W\xc3\xb3jcik\r\nLOCATION:Paw.A 013 lab.\r\nEND:VEVENT\r\nBEGIN:VEVENT\r\nSUMMARY:Probability and Statistics\r\nDTSTART:20260224T094500\r\nDTEND:20260224T111500\r\nDTSTAMP:20260525T151451\r\nUID:f3f824fd-4efb-4281-bf33-0dd6b5ef4627\r\nDESCRITION:prof. dr hab. Andrzej Soko\xc5\x82owski\r\nLOCATION:Paw.F 008\r\nEND:VEVENT\r\nBEGIN:VEVENT\r\nSUMMARY:Probability and Statistics\r\nDTSTART:20260224T131500\r\nDTEND:20260224T144500\r\nDTSTAMP:20260525T151451\r\nUID:ead81ed1-ea13-4002-a801-b2e7840f1f31\r\nDESCRITION:prof. dr hab. Andrzej Soko\xc5\x82owski\r\nLOCATION:Paw.A 07 lab.\r\nEND:VEVENT\r\nBEGIN:VEVENT\r\nSUMMARY:Discrete mathematics\r\nDTSTART:20260224T150000\r\nDTEND:20260224T163000\r\nDTSTAMP:20260525T151451\r\nUID:afbc68da-550f-41c9-8303-4568ba7ef2c5\r\nDESCRITION:dr Grzegorz Kosiorowski\r\nLOCATION:Rakowicka 16 sala 11\r\nEND:VEVENT\r\nBEGIN:VEVENT\r\nSUMMARY:Business Law\r\nDTSTART:20260224T183000\r\nDTEND:20260224T200000\r\nDTSTAMP:20260525T151451\r\nUID:c40aec17-1c95-48ce-b9c3-24a368f9f31a\r\nDESCRITION:dr Jacek Lachner\r\nLOCATION:Rakowicka 16 sala 11\r\nEND:VEVENT\r\nBEGIN:VEVENT\r\nSUMMARY:Operating Systems and Computer Networks\r\nDTSTART:20260226T080000\r\nDTEND:20260226T093000\r\nDTSTAMP:20260525T151451\r\nUID:7c1c489b-01cb-451d-9afe-db3fa0ba36bb\r\nDESCRITION:prof. UEK dr hab. Joanna Wyrobek\r\nLOCATION:Paw.F 008\r\nEND:VEVENT\r\nBEGIN:VEVENT\r\nSUMMARY: